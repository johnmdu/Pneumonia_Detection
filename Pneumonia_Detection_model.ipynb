# %% [markdown]
# <h2> <b>What is Pneumonia?</b></h2>
#
# <p> <blockquote> Pneumonia is an inflammatory condition of the lung affecting primarily the small air sacs known as alveoli.Symptoms typically include some combination of productive or dry cough, chest pain, fever and difficulty breathing. The severity of the condition is variable. Pneumonia is usually caused by infection with viruses or bacteria and less commonly by other microorganisms, certain medications or conditions such as autoimmune diseases.Risk factors include cystic fibrosis, chronic obstructive pulmonary disease (COPD), asthma, diabetes, heart failure, a history of smoking, a poor ability to cough such as following a stroke and a weak immune system. Diagnosis is often based on symptoms and physical examination. Chest X-ray, blood tests, and culture of the sputum may help confirm the diagnosis.The disease may be classified by where it was acquired, such as community- or hospital-acquired or healthcare-associated pneumonia.</blockquote> </p>

# %% [markdown]
# ![pathogenesis-lower-respiratory-tract-infection-18.png](data:image/png;base64,...)

# %% [markdown]
# <h2> <b> Bacterial Pneumonia </b></h2>
#
# <p> Pneumonia caused by a bacterium is called bacterial pneumonia. There are many types of bacteria that may cause bacterial pneumonia, but the most common type Streptococcus pneumoniae.
#
# Common symptoms of bacterial pneumonia include:
#
# * Chest pain
# * Shortness of breath
# * Sputum that is yellow or green mucus while coughing
# * Chills
# * Fever
# * Fatigue
#
# Bacterial pneumonia requires antibiotics for treatment; ideally, the antibiotic will target the specific type of bacteria. Steroids may also be used to improve breathing.
#  </p>
# <h2> <b> Viral Pneumonia </b></h2>
# <p>Approximately 30% of pneumonia cases are viral. This type of pneumonia typically occurs as a secondary infection from other viruses such as influenza, coronavirus, parainfluenza, adenovirus, and respiratory syncytial virus (RSV).
#
# These types of viruses spread through air droplets. For example, a sneeze or a cough may cause sputum an air droplet to spread through the air, or the virus could land on a doorknob or a surface that is touched, then brought to the nose or mouth.
#
# Symptoms of viral pneumonia are similar, although there are differences:
#
# * A dry cough (note that there is rarely sputum produced with viral pneumonia)
# *Fever
# *Chills
# *Chest pain
# *Shortness of breath
#
# While bacterial pneumonia is treated with antibiotics, this treatment will not help bacterial pneumonia. Viruses are not receptive to antibiotics. Occasionally, antiviral medications may be prescribed.
# </p>

# %% [markdown]
# # Import Libraries

# %%
import numpy as np 
import pandas as pd 

import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, AvgPool2D, MaxPool2D , Flatten , Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.callbacks import ReduceLROnPlateau
import cv2
import os

print(tf.__version__)
# Out:
# 2.3.0

# %% [markdown]
# # Load Data :

# %%
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150
def get_input_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        diag= ""
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                # Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) 
                if "bacteria" in img:
                    diag = [1,0,0] 
                elif "virus" in img:
                    diag = [0,1,0] 
                else:
                    diag = [0,0,1]              
                data.append([resized_arr, class_num, diag])
            except Exception as e:
                print(img, e)
    return np.array(data)

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
train = get_input_data('/content/gdrive/My Drive/chest_xray/train')
test = get_input_data('/content/gdrive/My Drive/chest_xray/test')
val = get_input_data('/content/gdrive/My Drive/chest_xray/val')

# %% [markdown]
# # Data Visualization and processing

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[-1][0], cmap='gray', )
plt.title(label='Normal')

plt.figure(figsize = (5,5))
plt.imshow(train[0][0], cmap='gray')
plt.title(label='Bacterial Pneumonia')

plt.figure(figsize = (5,5))
plt.imshow(train[1][0], cmap='gray')
plt.title(label='Viral Pneumonia')
# Out:
# Text(0.5, 1.0, 'Viral Pneumonia')

# %% [markdown]
# <h2> Printing initial data :</h2>

# %%
def display_set(one_set, order = ["pneumonia bacteria", "pneumonia virus", "normal"]):
    l = []
    for i in one_set:
        if i[2] == [1,0,0]:
            diag = "pneumonia bacteria"
        elif i[2] == [0,1,0]:
            diag = "pneumonia virus"
        else:
            diag = "normal"
        l.append(diag)
    sns.set_style('darkgrid')
    sns.countplot(l, order = order)

# %%
display_set(train)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
display_set(val)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
display_set(test)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# <h4> The training data seems unbalanced. The validation data has very less of viral pneumonia data.</h4>

# %% [markdown]
# <h3> Redistributing x-rays to create balanced train and validation dataset :</h3>

# %%
x_data = []
y_data = []

for feature, label, diag in train:
    x_data.append(feature)
    y_data.append(diag)

for feature, label, diag in test:
    x_data.append(feature)
    y_data.append(diag)
    
for feature, label, diag in val:
    x_data.append(feature)
    y_data.append(diag)

y_class_num = [np.where(np.asarray(r)==1)[0][0] for r in y_data]
sns.countplot(y_class_num).set_title('All data')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'All data')

# %% [markdown]
# <h3> Resizing test dataset:

# %%
samples = pd.DataFrame(y_class_num, columns = ['class_num'])
samples['diag'] = y_data
samples['img'] = x_data

smallest_diag_count = samples['class_num'].value_counts().min()
print("number of sampels per category", smallest_diag_count)

class0 = samples[samples['class_num'] == 0].sample(smallest_diag_count)
class1 = samples[samples['class_num'] == 1].sample(smallest_diag_count)
class2 = samples[samples['class_num'] == 2].sample(smallest_diag_count)

samples_under = pd.concat([class0, class1, class2], axis=0)

x = samples_under['img'].tolist()
y = samples_under['diag'].tolist()
sns.countplot(samples_under['class_num']).set_title('Final data')
# Out:
# number of sampels per category 1498
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Final data')

# %% [markdown]
# Splitting data into 70% train, 15% validation and 15% test

# %%
# shuffling the samples to have matching ditributions regarding the differents sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, shuffle=True)
sns.countplot([np.where(np.asarray(r)==1)[0][0] for r in y_train]).set_title('Training data')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Training data')

# %%
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, shuffle=False)
sns.countplot([np.where(np.asarray(r)==1)[0][0] for r in y_val]).set_title('Validation data')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Validation data')

# %%
sns.countplot([np.where(np.asarray(r)==1)[0][0] for r in y_test]).set_title('Test data')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Test data')

# %% [markdown]
# We perform a grayscale normalization to reduce the effect of illumination's differences.Moreover the CNN converges faster on [0..1] data than on [0..255].

# %%
# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255

# %%
# resize data for deep learning 
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %% [markdown]
# DATA AUGMENTATION

# %%
# With data augmentation to prevent overfitting and handling the imbalance in dataset

train_datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = False,  # randomly flip images
        vertical_flip=False)  # randomly flip images
train_datagen.fit(x_train)

valid_datagen = ImageDataGenerator()

test_datagen = ImageDataGenerator()


train_generator = train_datagen.flow(
    x_train,
    y_train,
    batch_size = 32)

validation_generator = valid_datagen.flow(
    x_val,
    y_val)

test_generator = test_datagen.flow(
    x_test,
    y_test)

# %% [markdown]
# TRAIN MODEL

# %%
model = Sequential()
model.add(Conv2D(input_shape=(150,150,1),filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Flatten())
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=4096,activation="relu"))



model.add(Dense(units=3, activation="softmax"))
from keras.optimizers import RMSprop
opt = RMSprop(lr=0.00001)
model.compile(optimizer = opt , loss = 'categorical_crossentropy' , metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_39 (Conv2D)           (None, 150, 150, 64)      640
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 150, 150, 64)      36928
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 75, 75, 128)       73856
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 75, 75, 128)       147584
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 37, 37, 256)       295168
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 37, 37, 256)       590080
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 37, 37, 256)       590080
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 18, 18, 256)       0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 18, 18, 512)       1180160
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 18, 18, 512)       2359808
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 18, 18, 512)       2359808
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 9, 9, 512)         0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 9, 9, 512)         2359808
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 9, 9, 512)         2359808
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 9, 9, 512)         2359808
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 4096)              33558528
# _________________________________________________________________
# dense_10 (Dense)             (None, 4096)              16781312
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 12291
# =================================================================
# Total params: 65,065,667
# Trainable params: 65,065,667
# Non-trainable params: 0
# _________________________________________________________________

# %%
class_weight = {0: 3, 1: 3, 2: 1}
loops = 100
history = []

for x in range(loops): 
    history.append(model.fit(
            train_generator,
            steps_per_epoch=97,
            epochs=1,
            validation_data=test_generator,
            validation_steps=20,
            class_weight=class_weight))
# Out:
#  2/97 [..............................] - ETA: 9s - loss: 2.7094 - accuracy: 0.3750WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0453s vs `on_train_batch_end` time: 0.0802s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 2.3687 - accuracy: 0.3427 - val_loss: 1.1962 - val_accuracy: 0.3406
#  2/97 [..............................] - ETA: 9s - loss: 2.3437 - accuracy: 0.3125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0439s vs `on_train_batch_end` time: 0.0783s). Check your callbacks.
# 97/97 [==============================] - 12s 127ms/step - loss: 2.2659 - accuracy: 0.3538 - val_loss: 0.9966 - val_accuracy: 0.4187
#  2/97 [..............................] - ETA: 9s - loss: 2.2726 - accuracy: 0.3281WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0481s vs `on_train_batch_end` time: 0.0786s). Check your callbacks.
# 97/97 [==============================] - 12s 127ms/step - loss: 2.1179 - accuracy: 0.4680 - val_loss: 0.8568 - val_accuracy: 0.6844
#  2/97 [..............................] - ETA: 9s - loss: 2.1514 - accuracy: 0.5312WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0420s vs `on_train_batch_end` time: 0.0781s). Check your callbacks.
# 97/97 [==============================] - 12s 127ms/step - loss: 1.9891 - accuracy: 0.5592 - val_loss: 0.7924 - val_accuracy: 0.6734
#  2/97 [..............................] - ETA: 9s - loss: 1.8794 - accuracy: 0.6406WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0416s vs `on_train_batch_end` time: 0.0783s). Check your callbacks.
# 97/97 [==============================] - 12s 127ms/step - loss: 1.9251 - accuracy: 0.5953 - val_loss: 0.7475 - val_accuracy: 0.7016
#  2/97 [..............................] - ETA: 9s - loss: 1.8807 - accuracy: 0.6250WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0427s vs `on_train_batch_end` time: 0.0786s). Check your callbacks.
# 97/97 [==============================] - 12s 127ms/step - loss: 1.8473 - accuracy: 0.6199 - val_loss: 1.1336 - val_accuracy: 0.5031
#  2/97 [..............................] - ETA: 9s - loss: 2.0465 - accuracy: 0.5781WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0427s vs `on_train_batch_end` time: 0.0778s). Check your callbacks.
# 97/97 [==============================] - 12s 127ms/step - loss: 1.8336 - accuracy: 0.6193 - val_loss: 0.7445 - val_accuracy: 0.6734
#  2/97 [..............................] - ETA: 9s - loss: 1.8919 - accuracy: 0.5469WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0396s vs `on_train_batch_end` time: 0.0781s). Check your callbacks.
# 97/97 [==============================] - 12s 126ms/step - loss: 1.7673 - accuracy: 0.6414 - val_loss: 0.6667 - val_accuracy: 0.7266
#  2/97 [..............................] - ETA: 9s - loss: 2.0663 - accuracy: 0.5312WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0394s vs `on_train_batch_end` time: 0.0782s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.7332 - accuracy: 0.6547 - val_loss: 0.6859 - val_accuracy: 0.7281
#  2/97 [..............................] - ETA: 9s - loss: 1.5755 - accuracy: 0.6406WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0398s vs `on_train_batch_end` time: 0.0784s). Check your callbacks.
# 97/97 [==============================] - 12s 127ms/step - loss: 1.6772 - accuracy: 0.6696 - val_loss: 0.6152 - val_accuracy: 0.7219
#  2/97 [..............................] - ETA: 9s - loss: 1.4761 - accuracy: 0.7031WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0440s vs `on_train_batch_end` time: 0.0773s). Check your callbacks.
# 97/97 [==============================] - 12s 127ms/step - loss: 1.6665 - accuracy: 0.6712 - val_loss: 0.5978 - val_accuracy: 0.7500
#  2/97 [..............................] - ETA: 9s - loss: 1.7578 - accuracy: 0.6406WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0420s vs `on_train_batch_end` time: 0.0780s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.6379 - accuracy: 0.6751 - val_loss: 0.5799 - val_accuracy: 0.7453
#  2/97 [..............................] - ETA: 9s - loss: 1.8630 - accuracy: 0.5469WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0442s vs `on_train_batch_end` time: 0.0786s). Check your callbacks.
# 97/97 [==============================] - 12s 127ms/step - loss: 1.6096 - accuracy: 0.6884 - val_loss: 0.6152 - val_accuracy: 0.7297
#  2/97 [..............................] - ETA: 9s - loss: 1.6838 - accuracy: 0.6719WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0409s vs `on_train_batch_end` time: 0.0775s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.6143 - accuracy: 0.6884 - val_loss: 0.5815 - val_accuracy: 0.7625
#  2/97 [..............................] - ETA: 9s - loss: 1.2509 - accuracy: 0.7812WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0449s vs `on_train_batch_end` time: 0.0763s). Check your callbacks.
# 97/97 [==============================] - 12s 127ms/step - loss: 1.5467 - accuracy: 0.7121 - val_loss: 0.5682 - val_accuracy: 0.7719
#  2/97 [..............................] - ETA: 9s - loss: 1.5783 - accuracy: 0.6719WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0488s vs `on_train_batch_end` time: 0.0782s). Check your callbacks.
# 97/97 [==============================] - 12s 127ms/step - loss: 1.5326 - accuracy: 0.7079 - val_loss: 0.5980 - val_accuracy: 0.7422
#  2/97 [..............................] - ETA: 9s - loss: 1.3016 - accuracy: 0.7969WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0488s vs `on_train_batch_end` time: 0.0787s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.5371 - accuracy: 0.7089 - val_loss: 0.6009 - val_accuracy: 0.7547
#  2/97 [..............................] - ETA: 9s - loss: 1.5606 - accuracy: 0.7656WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0402s vs `on_train_batch_end` time: 0.0785s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.5135 - accuracy: 0.7209 - val_loss: 0.5445 - val_accuracy: 0.7844
#  2/97 [..............................] - ETA: 9s - loss: 1.3410 - accuracy: 0.7656WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0437s vs `on_train_batch_end` time: 0.0781s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.4778 - accuracy: 0.7332 - val_loss: 0.5430 - val_accuracy: 0.7828
#  2/97 [..............................] - ETA: 9s - loss: 1.4100 - accuracy: 0.7344WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0422s vs `on_train_batch_end` time: 0.0782s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.4653 - accuracy: 0.7345 - val_loss: 0.5300 - val_accuracy: 0.7859
#  2/97 [..............................] - ETA: 9s - loss: 1.9040 - accuracy: 0.5781WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0450s vs `on_train_batch_end` time: 0.0781s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.4977 - accuracy: 0.7267 - val_loss: 0.5044 - val_accuracy: 0.8000
# 97/97 [==============================] - 12s 128ms/step - loss: 1.4167 - accuracy: 0.7384 - val_loss: 0.5519 - val_accuracy: 0.7797
#  2/97 [..............................] - ETA: 9s - loss: 1.1080 - accuracy: 0.8281WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0403s vs `on_train_batch_end` time: 0.0790s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.4419 - accuracy: 0.7374 - val_loss: 0.5421 - val_accuracy: 0.8047
#  2/97 [..............................] - ETA: 9s - loss: 1.5242 - accuracy: 0.6875WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0424s vs `on_train_batch_end` time: 0.0790s). Check your callbacks.
# 97/97 [==============================] - 12s 127ms/step - loss: 1.4214 - accuracy: 0.7407 - val_loss: 0.5324 - val_accuracy: 0.7844
#  2/97 [..............................] - ETA: 9s - loss: 1.0365 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0438s vs `on_train_batch_end` time: 0.0781s). Check your callbacks.
# 97/97 [==============================] - 12s 127ms/step - loss: 1.3857 - accuracy: 0.7413 - val_loss: 0.5167 - val_accuracy: 0.7859
#  2/97 [..............................] - ETA: 9s - loss: 1.3128 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0401s vs `on_train_batch_end` time: 0.0780s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.3916 - accuracy: 0.7498 - val_loss: 0.4898 - val_accuracy: 0.8016
#  2/97 [..............................] - ETA: 9s - loss: 1.3549 - accuracy: 0.7344WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0443s vs `on_train_batch_end` time: 0.0781s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.3785 - accuracy: 0.7579 - val_loss: 0.5009 - val_accuracy: 0.7812
#  2/97 [..............................] - ETA: 9s - loss: 1.4077 - accuracy: 0.7500WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0398s vs `on_train_batch_end` time: 0.0780s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.3817 - accuracy: 0.7549 - val_loss: 0.5237 - val_accuracy: 0.8000
#  2/97 [..............................] - ETA: 9s - loss: 1.4206 - accuracy: 0.6875WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0436s vs `on_train_batch_end` time: 0.0786s). Check your callbacks.
# 97/97 [==============================] - 12s 127ms/step - loss: 1.3575 - accuracy: 0.7595 - val_loss: 0.5203 - val_accuracy: 0.7859
#  2/97 [..............................] - ETA: 9s - loss: 1.8358 - accuracy: 0.7031WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0427s vs `on_train_batch_end` time: 0.0787s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.3585 - accuracy: 0.7605 - val_loss: 0.4872 - val_accuracy: 0.7953
#  2/97 [..............................] - ETA: 9s - loss: 1.5791 - accuracy: 0.7344WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0463s vs `on_train_batch_end` time: 0.0782s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.3514 - accuracy: 0.7553 - val_loss: 0.4987 - val_accuracy: 0.7875
#  2/97 [..............................] - ETA: 9s - loss: 1.0049 - accuracy: 0.8438WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0427s vs `on_train_batch_end` time: 0.0779s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.3219 - accuracy: 0.7670 - val_loss: 0.5388 - val_accuracy: 0.7937
#  2/97 [..............................] - ETA: 9s - loss: 1.2223 - accuracy: 0.7812WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0397s vs `on_train_batch_end` time: 0.0783s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.3394 - accuracy: 0.7663 - val_loss: 0.5036 - val_accuracy: 0.7984
#  2/97 [..............................] - ETA: 9s - loss: 1.2018 - accuracy: 0.7812WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0396s vs `on_train_batch_end` time: 0.0783s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.3147 - accuracy: 0.7705 - val_loss: 0.5052 - val_accuracy: 0.8062
#  2/97 [..............................] - ETA: 9s - loss: 1.2007 - accuracy: 0.7812WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0463s vs `on_train_batch_end` time: 0.0783s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.3006 - accuracy: 0.7822 - val_loss: 0.5735 - val_accuracy: 0.7453
#  2/97 [..............................] - ETA: 9s - loss: 1.4393 - accuracy: 0.7188WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0432s vs `on_train_batch_end` time: 0.0811s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.2978 - accuracy: 0.7741 - val_loss: 0.4834 - val_accuracy: 0.7953
#  2/97 [..............................] - ETA: 9s - loss: 1.2082 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0403s vs `on_train_batch_end` time: 0.0782s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.2973 - accuracy: 0.7829 - val_loss: 0.4667 - val_accuracy: 0.8078
#  2/97 [..............................] - ETA: 9s - loss: 0.8233 - accuracy: 0.8594WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0435s vs `on_train_batch_end` time: 0.0792s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.2732 - accuracy: 0.7790 - val_loss: 0.4847 - val_accuracy: 0.8094
#  2/97 [..............................] - ETA: 9s - loss: 1.1215 - accuracy: 0.8281WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0462s vs `on_train_batch_end` time: 0.0784s). Check your callbacks.
# 97/97 [==============================] - 12s 129ms/step - loss: 1.2876 - accuracy: 0.7812 - val_loss: 0.4977 - val_accuracy: 0.7828
#  2/97 [..............................] - ETA: 9s - loss: 1.1171 - accuracy: 0.8750WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0428s vs `on_train_batch_end` time: 0.0779s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.2598 - accuracy: 0.7877 - val_loss: 0.4797 - val_accuracy: 0.7984
#  2/97 [..............................] - ETA: 9s - loss: 1.3836 - accuracy: 0.7188WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0458s vs `on_train_batch_end` time: 0.0782s). Check your callbacks.
# 97/97 [==============================] - 12s 129ms/step - loss: 1.2652 - accuracy: 0.7832 - val_loss: 0.5525 - val_accuracy: 0.7937
#  2/97 [..............................] - ETA: 9s - loss: 1.1024 - accuracy: 0.8438WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0434s vs `on_train_batch_end` time: 0.0796s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.2555 - accuracy: 0.7799 - val_loss: 0.4675 - val_accuracy: 0.8078
#  2/97 [..............................] - ETA: 9s - loss: 1.1373 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0425s vs `on_train_batch_end` time: 0.0781s). Check your callbacks.
# 97/97 [==============================] - 12s 129ms/step - loss: 1.2563 - accuracy: 0.7780 - val_loss: 0.5320 - val_accuracy: 0.7875
#  2/97 [..............................] - ETA: 9s - loss: 1.4132 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0421s vs `on_train_batch_end` time: 0.0789s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.2533 - accuracy: 0.7877 - val_loss: 0.4673 - val_accuracy: 0.7969
#  2/97 [..............................] - ETA: 9s - loss: 0.9745 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0462s vs `on_train_batch_end` time: 0.0788s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.2509 - accuracy: 0.7877 - val_loss: 0.4739 - val_accuracy: 0.7891
#  2/97 [..............................] - ETA: 9s - loss: 1.1770 - accuracy: 0.7812WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0452s vs `on_train_batch_end` time: 0.0781s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.2373 - accuracy: 0.7881 - val_loss: 0.4979 - val_accuracy: 0.7828
#  2/97 [..............................] - ETA: 9s - loss: 1.4827 - accuracy: 0.7656WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0446s vs `on_train_batch_end` time: 0.0781s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.2245 - accuracy: 0.7897 - val_loss: 0.4665 - val_accuracy: 0.8047
#  2/97 [..............................] - ETA: 9s - loss: 0.9170 - accuracy: 0.8281WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0438s vs `on_train_batch_end` time: 0.0783s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.2427 - accuracy: 0.7848 - val_loss: 0.4415 - val_accuracy: 0.8156
#  2/97 [..............................] - ETA: 9s - loss: 1.2270 - accuracy: 0.7656WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0426s vs `on_train_batch_end` time: 0.0788s). Check your callbacks.
# 97/97 [==============================] - 12s 129ms/step - loss: 1.2073 - accuracy: 0.7945 - val_loss: 0.4777 - val_accuracy: 0.8219
#  2/97 [..............................] - ETA: 9s - loss: 1.0107 - accuracy: 0.8281WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0403s vs `on_train_batch_end` time: 0.0786s). Check your callbacks.
# 97/97 [==============================] - 12s 129ms/step - loss: 1.2179 - accuracy: 0.7994 - val_loss: 0.4523 - val_accuracy: 0.8156
#  2/97 [..............................] - ETA: 9s - loss: 0.9653 - accuracy: 0.8594WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0457s vs `on_train_batch_end` time: 0.0782s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.2133 - accuracy: 0.7994 - val_loss: 0.4813 - val_accuracy: 0.7953
#  2/97 [..............................] - ETA: 9s - loss: 1.4112 - accuracy: 0.7656WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0439s vs `on_train_batch_end` time: 0.0782s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.2048 - accuracy: 0.7988 - val_loss: 0.4542 - val_accuracy: 0.8203
#  2/97 [..............................] - ETA: 9s - loss: 1.1121 - accuracy: 0.8281WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0472s vs `on_train_batch_end` time: 0.0784s). Check your callbacks.
# 97/97 [==============================] - 12s 129ms/step - loss: 1.1833 - accuracy: 0.8075 - val_loss: 0.5317 - val_accuracy: 0.7797
#  2/97 [..............................] - ETA: 9s - loss: 1.0725 - accuracy: 0.7969WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0439s vs `on_train_batch_end` time: 0.0781s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.2089 - accuracy: 0.7884 - val_loss: 0.4585 - val_accuracy: 0.8172
#  2/97 [..............................] - ETA: 9s - loss: 0.9358 - accuracy: 0.8750WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0403s vs `on_train_batch_end` time: 0.0782s). Check your callbacks.
# 97/97 [==============================] - 12s 129ms/step - loss: 1.1827 - accuracy: 0.8088 - val_loss: 0.5238 - val_accuracy: 0.8031
#  2/97 [..............................] - ETA: 9s - loss: 1.1596 - accuracy: 0.8438WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0471s vs `on_train_batch_end` time: 0.0782s). Check your callbacks.
# 97/97 [==============================] - 12s 129ms/step - loss: 1.1581 - accuracy: 0.8098 - val_loss: 0.4524 - val_accuracy: 0.8000
#  2/97 [..............................] - ETA: 9s - loss: 1.4001 - accuracy: 0.7500WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0438s vs `on_train_batch_end` time: 0.0782s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.2096 - accuracy: 0.7913 - val_loss: 0.5062 - val_accuracy: 0.8000
#  2/97 [..............................] - ETA: 9s - loss: 1.2677 - accuracy: 0.8281WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0398s vs `on_train_batch_end` time: 0.0780s). Check your callbacks.
# 97/97 [==============================] - 12s 129ms/step - loss: 1.1727 - accuracy: 0.8075 - val_loss: 0.4780 - val_accuracy: 0.8141
#  2/97 [..............................] - ETA: 9s - loss: 1.1698 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0442s vs `on_train_batch_end` time: 0.0782s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.1596 - accuracy: 0.8040 - val_loss: 0.4608 - val_accuracy: 0.8016
#  2/97 [..............................] - ETA: 9s - loss: 1.2688 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0463s vs `on_train_batch_end` time: 0.0785s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.1646 - accuracy: 0.8092 - val_loss: 0.4667 - val_accuracy: 0.8062
#  2/97 [..............................] - ETA: 9s - loss: 1.0811 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0447s vs `on_train_batch_end` time: 0.0786s). Check your callbacks.
# 97/97 [==============================] - 12s 129ms/step - loss: 1.1451 - accuracy: 0.8124 - val_loss: 0.4499 - val_accuracy: 0.8109
#  2/97 [..............................] - ETA: 9s - loss: 0.8466 - accuracy: 0.8750WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0461s vs `on_train_batch_end` time: 0.0788s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.1592 - accuracy: 0.8072 - val_loss: 0.4694 - val_accuracy: 0.8109
#  2/97 [..............................] - ETA: 9s - loss: 1.1638 - accuracy: 0.7969WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0441s vs `on_train_batch_end` time: 0.0791s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.1528 - accuracy: 0.8072 - val_loss: 0.4458 - val_accuracy: 0.8234
#  2/97 [..............................] - ETA: 9s - loss: 0.8507 - accuracy: 0.8594WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0455s vs `on_train_batch_end` time: 0.0780s). Check your callbacks.
# 97/97 [==============================] - 12s 129ms/step - loss: 1.1358 - accuracy: 0.8137 - val_loss: 0.4536 - val_accuracy: 0.8141
#  2/97 [..............................] - ETA: 9s - loss: 1.1780 - accuracy: 0.8438WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0397s vs `on_train_batch_end` time: 0.0790s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.1422 - accuracy: 0.8130 - val_loss: 0.4821 - val_accuracy: 0.7922
#  2/97 [..............................] - ETA: 9s - loss: 1.1625 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0479s vs `on_train_batch_end` time: 0.0786s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.1387 - accuracy: 0.8143 - val_loss: 0.4580 - val_accuracy: 0.8125
#  2/97 [..............................] - ETA: 9s - loss: 1.3090 - accuracy: 0.7812WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0393s vs `on_train_batch_end` time: 0.0784s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.1391 - accuracy: 0.8137 - val_loss: 0.4627 - val_accuracy: 0.8266
#  2/97 [..............................] - ETA: 9s - loss: 1.0973 - accuracy: 0.8438WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0396s vs `on_train_batch_end` time: 0.0787s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.1379 - accuracy: 0.8130 - val_loss: 0.5032 - val_accuracy: 0.7875
#  2/97 [..............................] - ETA: 9s - loss: 1.3055 - accuracy: 0.7656WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0403s vs `on_train_batch_end` time: 0.0782s). Check your callbacks.
# 97/97 [==============================] - 12s 129ms/step - loss: 1.1031 - accuracy: 0.8199 - val_loss: 0.4527 - val_accuracy: 0.8297
#  2/97 [..............................] - ETA: 9s - loss: 0.9807 - accuracy: 0.8906WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0420s vs `on_train_batch_end` time: 0.0782s). Check your callbacks.
# 97/97 [==============================] - 13s 130ms/step - loss: 1.1139 - accuracy: 0.8160 - val_loss: 0.4395 - val_accuracy: 0.8078
#  2/97 [..............................] - ETA: 9s - loss: 1.0923 - accuracy: 0.8438WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0476s vs `on_train_batch_end` time: 0.0782s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.0987 - accuracy: 0.8241 - val_loss: 0.4699 - val_accuracy: 0.8188
#  2/97 [..............................] - ETA: 9s - loss: 1.2258 - accuracy: 0.8281WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0442s vs `on_train_batch_end` time: 0.0788s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.1158 - accuracy: 0.8186 - val_loss: 0.4782 - val_accuracy: 0.8062
#  2/97 [..............................] - ETA: 9s - loss: 0.8434 - accuracy: 0.8438WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0442s vs `on_train_batch_end` time: 0.0780s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.0946 - accuracy: 0.8238 - val_loss: 0.4613 - val_accuracy: 0.8078
#  2/97 [..............................] - ETA: 9s - loss: 0.8790 - accuracy: 0.8594WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0377s vs `on_train_batch_end` time: 0.0792s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.1081 - accuracy: 0.8202 - val_loss: 0.4691 - val_accuracy: 0.8188
#  2/97 [..............................] - ETA: 9s - loss: 1.1255 - accuracy: 0.8281WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0442s vs `on_train_batch_end` time: 0.0785s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.1127 - accuracy: 0.8189 - val_loss: 0.4881 - val_accuracy: 0.8109
#  2/97 [..............................] - ETA: 9s - loss: 0.8521 - accuracy: 0.8750WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0437s vs `on_train_batch_end` time: 0.0780s). Check your callbacks.
# 97/97 [==============================] - 13s 130ms/step - loss: 1.0985 - accuracy: 0.8315 - val_loss: 0.4722 - val_accuracy: 0.8094
#  2/97 [..............................] - ETA: 9s - loss: 0.8842 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0456s vs `on_train_batch_end` time: 0.0779s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.1018 - accuracy: 0.8156 - val_loss: 0.4370 - val_accuracy: 0.8188
#  2/97 [..............................] - ETA: 9s - loss: 1.3809 - accuracy: 0.7656WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0435s vs `on_train_batch_end` time: 0.0788s). Check your callbacks.
# 97/97 [==============================] - 12s 128ms/step - loss: 1.0782 - accuracy: 0.8264 - val_loss: 0.4536 - val_accuracy: 0.8109
#  2/97 [..............................] - ETA: 9s - loss: 1.2470 - accuracy: 0.7812WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0395s vs `on_train_batch_end` time: 0.0783s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.0761 - accuracy: 0.8241 - val_loss: 0.4320 - val_accuracy: 0.8172
#  2/97 [..............................] - ETA: 9s - loss: 0.8584 - accuracy: 0.8906WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0401s vs `on_train_batch_end` time: 0.0779s). Check your callbacks.
# 97/97 [==============================] - 12s 129ms/step - loss: 1.0756 - accuracy: 0.8270 - val_loss: 0.4892 - val_accuracy: 0.7891
#  2/97 [..............................] - ETA: 9s - loss: 1.2869 - accuracy: 0.7656WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0445s vs `on_train_batch_end` time: 0.0791s). Check your callbacks.
# 97/97 [==============================] - 13s 130ms/step - loss: 1.0792 - accuracy: 0.8225 - val_loss: 0.5430 - val_accuracy: 0.7703
#  2/97 [..............................] - ETA: 9s - loss: 1.3594 - accuracy: 0.7812WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0472s vs `on_train_batch_end` time: 0.0786s). Check your callbacks.
# 97/97 [==============================] - 13s 130ms/step - loss: 1.0801 - accuracy: 0.8338 - val_loss: 0.4439 - val_accuracy: 0.8219
#  2/97 [..............................] - ETA: 9s - loss: 1.2217 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0398s vs `on_train_batch_end` time: 0.0780s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.0809 - accuracy: 0.8335 - val_loss: 0.4325 - val_accuracy: 0.8234
#  2/97 [..............................] - ETA: 9s - loss: 0.8586 - accuracy: 0.8594WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0409s vs `on_train_batch_end` time: 0.0782s). Check your callbacks.
# 97/97 [==============================] - 13s 130ms/step - loss: 1.0913 - accuracy: 0.8251 - val_loss: 0.4440 - val_accuracy: 0.8266
#  2/97 [..............................] - ETA: 9s - loss: 0.9615 - accuracy: 0.8906WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0439s vs `on_train_batch_end` time: 0.0781s). Check your callbacks.
# 97/97 [==============================] - 13s 130ms/step - loss: 1.0504 - accuracy: 0.8360 - val_loss: 0.4508 - val_accuracy: 0.8125
#  2/97 [..............................] - ETA: 9s - loss: 0.7911 - accuracy: 0.9062WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0411s vs `on_train_batch_end` time: 0.0778s). Check your callbacks.
# 97/97 [==============================] - 12s 129ms/step - loss: 1.0502 - accuracy: 0.8241 - val_loss: 0.4518 - val_accuracy: 0.7984
#  2/97 [..............................] - ETA: 9s - loss: 0.9991 - accuracy: 0.8750WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0480s vs `on_train_batch_end` time: 0.0781s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.0547 - accuracy: 0.8354 - val_loss: 0.4491 - val_accuracy: 0.8109
#  2/97 [..............................] - ETA: 9s - loss: 0.9626 - accuracy: 0.8750WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0403s vs `on_train_batch_end` time: 0.0781s). Check your callbacks.
# 97/97 [==============================] - 13s 130ms/step - loss: 1.0504 - accuracy: 0.8306 - val_loss: 0.4815 - val_accuracy: 0.8156
#  2/97 [..............................] - ETA: 9s - loss: 1.1328 - accuracy: 0.8594WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0480s vs `on_train_batch_end` time: 0.0784s). Check your callbacks.
# 97/97 [==============================] - 13s 131ms/step - loss: 1.0447 - accuracy: 0.8254 - val_loss: 0.4735 - val_accuracy: 0.8000
#  2/97 [..............................] - ETA: 9s - loss: 1.0868 - accuracy: 0.8594WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0482s vs `on_train_batch_end` time: 0.0767s). Check your callbacks.
# 97/97 [==============================] - 13s 130ms/step - loss: 1.0304 - accuracy: 0.8380 - val_loss: 0.4441 - val_accuracy: 0.8141
#  2/97 [..............................] - ETA: 9s - loss: 0.8608 - accuracy: 0.8281WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0485s vs `on_train_batch_end` time: 0.0786s). Check your callbacks.
# 97/97 [==============================] - 13s 130ms/step - loss: 1.0208 - accuracy: 0.8361 - val_loss: 0.4793 - val_accuracy: 0.8016
# 97/97 [==============================] - 13s 130ms/step - loss: 1.0206 - accuracy: 0.8393 - val_loss: 0.4610 - val_accuracy: 0.8219
#  2/97 [..............................] - ETA: 9s - loss: 0.8919 - accuracy: 0.8594WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0417s vs `on_train_batch_end` time: 0.0784s). Check your callbacks.
# 97/97 [==============================] - 13s 130ms/step - loss: 1.0288 - accuracy: 0.8351 - val_loss: 0.4517 - val_accuracy: 0.8313
#  2/97 [..............................] - ETA: 9s - loss: 0.9479 - accuracy: 0.8906WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0453s vs `on_train_batch_end` time: 0.0788s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.0266 - accuracy: 0.8358 - val_loss: 0.6047 - val_accuracy: 0.7531
#  2/97 [..............................] - ETA: 9s - loss: 1.1935 - accuracy: 0.8281WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0474s vs `on_train_batch_end` time: 0.0783s). Check your callbacks.
# 97/97 [==============================] - 13s 130ms/step - loss: 1.0227 - accuracy: 0.8302 - val_loss: 0.4785 - val_accuracy: 0.7969
#  2/97 [..............................] - ETA: 9s - loss: 1.3020 - accuracy: 0.7656WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0401s vs `on_train_batch_end` time: 0.0780s). Check your callbacks.
# 97/97 [==============================] - 13s 130ms/step - loss: 1.0143 - accuracy: 0.8351 - val_loss: 0.4598 - val_accuracy: 0.8188
#  2/97 [..............................] - ETA: 9s - loss: 0.8267 - accuracy: 0.8438WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0408s vs `on_train_batch_end` time: 0.0779s). Check your callbacks.
# 97/97 [==============================] - 13s 129ms/step - loss: 1.0026 - accuracy: 0.8413 - val_loss: 0.4459 - val_accuracy: 0.8203
#  2/97 [..............................] - ETA: 9s - loss: 0.9018 - accuracy: 0.8594WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0443s vs `on_train_batch_end` time: 0.0781s). Check your callbacks.
# 97/97 [==============================] - 13s 131ms/step - loss: 1.0181 - accuracy: 0.8319 - val_loss: 0.4478 - val_accuracy: 0.8313
#  2/97 [..............................] - ETA: 9s - loss: 1.3037 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0404s vs `on_train_batch_end` time: 0.0781s). Check your callbacks.
# 97/97 [==============================] - 13s 131ms/step - loss: 1.0296 - accuracy: 0.8361 - val_loss: 0.4506 - val_accuracy: 0.8109
#  2/97 [..............................] - ETA: 9s - loss: 1.0630 - accuracy: 0.8750WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0459s vs `on_train_batch_end` time: 0.0783s). Check your callbacks.
# 97/97 [==============================] - 13s 131ms/step - loss: 1.0055 - accuracy: 0.8462 - val_loss: 0.4643 - val_accuracy: 0.8047

# %%
print("Loss of the model is - " , model.evaluate(x_val,y_val)[0]*100)
print("Accuracy of the model is - " , model.evaluate(x_val,y_val)[1]*100 , "%")
# Out:
# 22/22 [==============================] - 1s 41ms/step - loss: 0.4678 - accuracy: 0.8086
# Loss of the model is -  46.77508771419525
# 22/22 [==============================] - 1s 33ms/step - loss: 0.4678 - accuracy: 0.8086
# Accuracy of the model is -  80.86053133010864 %

# %%
print(history[0].history)
# Out:
# {'loss': [2.3711178302764893], 'accuracy': [0.3330087661743164], 'val_loss': [1.2186492681503296], 'val_accuracy': [0.3421874940395355]}

# %%
epochs = [i for i in range(100)]
fig , ax = plt.subplots(1,2)
train_acc = []
train_loss = []
val_acc = []
val_loss = []
for h in history:
    train_acc.append(h.history['accuracy'])
    train_loss.append(h.history['loss'])    
    val_acc.append(h.history['val_accuracy'])
    val_loss.append(h.history['val_loss'])
fig.set_size_inches(20,10)

ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'ro-' , label = 'Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'r-o' , label = 'Validation Loss')
ax[1].set_title('Testing Accuracy & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Training & Validation Loss")
plt.show()

# %%
predictions = model.predict_classes(x_test)
y_test_num = [np.where(r==1)[0][0] for r in y_test]
names = ['Pneumonia Bacteria', 'Pneumonia Virus','Normal']


print(classification_report(y_test_num, predictions, target_names = names))
# Out:
# WARNING:tensorflow:From <ipython-input-23-f7104ff3924c>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#                     precision    recall  f1-score   support
#
# Pneumonia Bacteria       0.79      0.74      0.77       218
#    Pneumonia Virus       0.71      0.78      0.74       227
#             Normal       0.94      0.91      0.92       230
#
#           accuracy                           0.81       675
#          macro avg       0.82      0.81      0.81       675
#       weighted avg       0.82      0.81      0.81       675

# %%
cm = confusion_matrix(y_test_num,predictions)
cm = pd.DataFrame(cm , index = names , columns = names)
cm.index.name = 'Actual'
cm.columns.name = 'Predicted'

group_counts = ["{0:0.0f}".format(value) for value in cm.to_numpy().flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cm.to_numpy().flatten()/np.sum(cm.to_numpy())]
labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_counts,group_percentages)]
labels = np.asarray(labels).reshape(3,3)

plt.figure(figsize = (10,10))
sns.heatmap(cm,
            annot=labels,
            cmap= "coolwarm",
            linecolor = 'black',
            linewidth = 1,
            fmt='')
